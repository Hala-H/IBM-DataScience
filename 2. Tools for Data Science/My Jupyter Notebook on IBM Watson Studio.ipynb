# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Hala Haneya

# %% [markdown]
# Computer Science Student

# %% [markdown]
# *I am interested in data science because I enjoy creating a story out of data to give insights and find patterns.*

# %% [markdown]
# ### My code in cell 5 will return the sum of two numbers.

# %%
def sum(x, y):
    return x + y

sum(10, 11)
# Out:
# 21

# %% [markdown]
# <hr>
#
# Click [on this link](https://www.calculator.net/) to go to check the answer of the sum.
# This table shows the famous numbers in the world:
#
# | Number | Name          |
# | ------------|:----------------------:|
# | 1.61803      | The Golden Ratio |
# | 3.142 | Pi     |
# | 911 | Emergency call      |
# | 9.81 | Gravitational constant|
#
# <hr>
#
# > "Obvious is the most `dangerous` word in Mathematics." - *E.T Bell*
#
# E.T Bell:
# ![alt text][logo]
#
# [logo]: https://upload.wikimedia.org/wikipedia/commons/a/a0/E_T_Bell.jpg "E.T Bell"
